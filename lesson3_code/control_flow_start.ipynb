# %% [markdown]
# # conditonal statement
#
# - if
# - elif
# - else

# %%
a = 1

# %% [markdown]
# # looping statement
#
# - while
# - for

# %% [markdown]
# # loop control statement
#
# - break :  terminates the current loop immediately when encountered.
# - continue : to skip the current iteration and move to the next iteration of the loop
# - pass : placeholder that does nothing when executed
