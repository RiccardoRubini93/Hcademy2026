# %% [markdown]
# usiamo i decoratori per fare prodiling del codice :
# - scriviamo una serie di sunzione sum_N -> calcolano la somma dei primi N numeri
# - sviluppare un decoratore @log_time che mi permetta di profilare le performance dell'algoritmo
#
# - ciclo for
# - funzione sum
# - numpy
# - definizione n*(n+1)/2

# %% [markdown]
# import time
#
# decorator template
#
# def log_time(func):
#
#     def wrap(*args,**kwargs):
#
#         start_time
#         result = func(*args,**kwargs) -> la vostra operazione
#         end_time
#         print('elsapsed time ' {start - end })
#         return result
#
#     return wrap

# %%
import time 

a = time.time()
time.sleep(1)
b = time.time() 

print(b-a)
# Out:
# 1.0020217895507812
